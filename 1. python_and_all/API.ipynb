# %%
## https://codingninjas.in/api/v3courses
## https://api.github.com/events
## https://dog.ceo/api/breeds/list/all
import requests
response = requests.get('https://codingninjas.in/api/v3/courses')
print(response.status_code)
print(response.encoding)
# print(response.text)
print(response.url)
header_info = response.headers
print(header_info)
print('\n')
print(header_info['Date'])
print(header_info['Content-Type'])
# Out:
# 200
# ISO-8859-1
# https://www.codingninjas.com:443/
# {'Content-Type': 'text/html', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'x-amz-id-2': 'hgrHPp9BiecKiZjfqbkLnQBTEffzby4aAH//rAB2dmUM9Tg1YGn+tsquNWQFTlZIpqSE6+s9PqI=', 'x-amz-request-id': '7TE02GGKPM76KZ7C', 'Last-Modified': 'Thu, 19 Sep 2024 13:24:21 GMT', 'Server': 'AmazonS3', 'Content-Encoding': 'br', 'Date': 'Fri, 20 Sep 2024 17:00:29 GMT', 'Cache-Control': 'must-revalidate, max-age=300', 'ETag': 'W/"616f6c5e115e7acaf5754c76fc41150e"', 'Vary': 'Accept-Encoding', 'X-Cache': 'Hit from cloudfront', 'Via': '1.1 ada0b90285266ac732e13cada7b6f918.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'DEL54-P7', 'X-Amz-Cf-Id': 'TbuxkTC33fBCm7WjJwen11edKnvZ-kvEwF8cfwq2_KTuWNKNjICvSg==', 'Age': '75'}
#
#
# Fri, 20 Sep 2024 17:00:29 GMT
# text/html

# %%
import json 
json_data = '{"Student" : "Mohit"}'
python_data = json.loads(json_data)
print(python_data)
print(type(python_data))
print(python_data['Student'])
# Out:
# {'Student': 'Mohit'}
# <class 'dict'>
# Mohit

# %%
import json
python_data = json.loads(response.text)
print(type(python_data))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[28], line 4
#       2 import requests
#       3 response = requests.get('https://codingninjas.in/api/v3/courses')
# ----> 4 python_data = json.loads(response.text)
#       5 print(type(python_data))
#
# File ~\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\anaconda3\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
# ...

# %%
import requests
import json

response = requests.get('https://codingninjas.in/api/v3courses')

# Check if the request was successful
if response.status_code == 200:
    print("Response Text:", response.text)  # Check the raw response content

    try:
        python_data = json.loads(response.text)
        print(type(python_data))
    except json.JSONDecodeError as e:
        print(f"JSON decode error: {e}")
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
# Out:
# Response Text: <!DOCTYPE html><html lang="en"><head>
#     <meta charset="utf-8">
#     <title>Coding Ninjas</title>
#
#     <meta name="google-site-verification" content="ASe_HQRsu8j61tGt95RROjXi07M380nMuoJ0Mu9rytk">
#     <meta name="title" content="Coding Ninjas">
#     <meta name="author" content="Coding Ninjas">
#     <meta property="og:title" content="Coding Ninjas">
#     <meta name="description" content="Best Programming Institute in India">
#     <meta property="og:description" content="Best Programming Institute in India">
#     <meta property="og:image" content="https://files.codingninjas.com/codingninjas-.webp">
#     <meta property="og:image:width" content="1800">
#     <meta property="og:image:height" content="942">
#
#     <script>
#       const NON_DELAYED_PATH_ARR = ['/checkout'];
#       let windowLoaded = false;
#       window.pushEventsToQueue = true;
#       window.gtmEventQueue = [];
#       window.gtmEcommerceQueue = [];
#       window.gtmScriptInit = false;
# ...

# %%
p = requests.get('https://dog.ceo/api/breeds/list/all')
python_data = p.json()
print(type(python_data))

for key, val in python_data['message'].items() :
    print(key, ":", len(val))
# Out:
# <class 'dict'>
# affenpinscher : 0
# african : 0
# airedale : 0
# akita : 0
# appenzeller : 0
# australian : 2
# bakharwal : 1
# basenji : 0
# beagle : 0
# bluetick : 0
# borzoi : 0
# bouvier : 0
# boxer : 0
# brabancon : 0
# briard : 0
# buhund : 1
# bulldog : 3
# bullterrier : 1
# cattledog : 1
# cavapoo : 0
# chihuahua : 0
# chippiparai : 1
# chow : 0
# clumber : 0
# cockapoo : 0
# collie : 1
# coonhound : 0
# corgi : 1
# cotondetulear : 0
# dachshund : 0
# dalmatian : 0
# dane : 1
# danish : 1
# deerhound : 1
# dhole : 0
# dingo : 0
# doberman : 0
# elkhound : 1
# entlebucher : 0
# eskimo : 0
# finnish : 1
# frise : 1
# gaddi : 1
# germanshepherd : 0
# greyhound : 2
# groenendael : 0
# havanese : 0
# hound : 7
# husky : 0
# keeshond : 0
# kelpie : 0
# kombai : 0
# komondor : 0
# kuvasz : 0
# labradoodle : 0
# labrador : 0
# leonberg : 0
# lhasa : 0
# malamute : 0
# malinois : 0
# maltese : 0
# mastiff : 4
# mexicanhairless : 0
# mix : 0
# mountain : 2
# mudhol : 1
# ...

# %%
for i in python_data['message']['hound']:
    print(i)
# Out:
# afghan
# basset
# blood
# english
# ibizan
# plott
# walker

# %%
for i in python_data['message']['poodle']:
    print(i)
# Out:
# medium
# miniature
# standard
# toy

# %%
import requests
response = requests.get('https://codingninjas.in/api/v3/courses')
python_data = response.json()
for i in python_data['data']['courses']:
    if(i['available_online'] == True):
        print(i['name'].strip())
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %%
a = requests.get('https://api.openaq.org/v1/cities', params = {"country" : "AE"})
print(a.status_code)
print(a.json())
print(a.url)
# Out:
# 401
# {'message': 'API KEY missing from x-api-key header'}
# https://api.openaq.org/v1/cities?country=AE

# %%
import requests
response = requests.get('https://swapi.co/api/planets/', params = {"page" : 2})
data = response.json()
for i in data['results']:
    print(i['name'])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %%
a = requests.get('https://www.metaweather.com/api/location/search/', params = {"query": "Delhi"})
print(a.status_code)
print(a.url)
print(a.json())
# Out:
# ---------------------------------------------------------------------------
# SSLEOFError                               Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
# --> 466     self._validate_conn(conn)
#     467 except (SocketTimeout, BaseSSLError) as e:
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:652, in HTTPSConnection.connect(self)
#     650 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 652 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
# ...

# %%
import requests
from requests.auth import HTTPBasicAuth
a = requests.get('https://api.github.com/user', auth = ('Gorisha2004', 'Mummy@papa2'))
print(a.status_code)
# Out:
# 401
