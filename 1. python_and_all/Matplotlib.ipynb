# %%
import matplotlib.pyplot as plt
import numpy as np

# Example integer arrays for X and Y
X = np.array([1, 2, 4, 6, 8, 10, 12])
Y = np.array([15, 30, 45, 65, 80, 95, 110])

# Plot the graph between X and Y
plt.plot(X, Y, marker='o')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Graph between X and Y')
plt.grid(True)
plt.show()

# Find the value of Y when X is 8
y_value = np.interp(8, X, Y)

# Calculate the lower and upper limits for Y range
lower_limit = (int(y_value) // 10) * 10
upper_limit = lower_limit + 10

# Print the range of Y
print(f"The range of Y when X is 8: [{lower_limit}, {upper_limit}]")
# Out:
# The range of Y when X is 8: [80, 90]

# %%
x = np.arange(0,40,2)
y = 2**x
plt.plot(x,y,"b--")
plt.show()

# %%
x = np.arange(0,40,2)
y = x
plt.xlabel('x')
plt.ylabel('y')
x1 = [0,1,2,3,4,5,6,7,9,10]
y1 = [1,2,5,10,17,26,37,50,82,101]
plt.plot(x1, y1, label='x[i]=x[i]^2 +1', color = "grey", linewidth = 5)
plt.plot(x, y, label='x[i]=y[i]', color = "green", linewidth = 5)
plt.legend()
plt.show()

# %% [markdown]
# ## Pie graph

# %%
import matplotlib.pyplot as plt
company = ['HP', 'Dell', 'Asus', 'Lenovo', 'Acer']
sold = [12000, 43000, 15000, 22000, 13000]
plt.pie(sold, labels = company, autopct = "%.1f%%", counterclock = False, startangle = 0)
plt.axis("equal")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
height = [189,185,195,149,189,147,154,174,169,195,159,192,155,191,153,157,140,144,172,157]
weight = [87,110,104,61,104,92,111,90,103,81,80,101,51,79,107,110,129,145,139,110] 
plt.hist(height, bins = 5, edgecolor = 'black')
plt.hist(weight, bins = 5, edgecolor = 'black')
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
import collections
with open('Datasets/amazon_jobs_dataset.csv', encoding ='UTF-8') as file_obj:
    file_data = csv.DictReader(file_obj, skipinitialspace=True)

    dct = {}
    for row in file_data:
        date = row['Posting_date'].split()
        key = date[2]
        if key in dct:
            dct[key] += 1
        else:
            dct[key] = 1
ord_dct = collections.OrderedDict(sorted(dct.items()))                                  
plt.plot(list(ord_dct.keys()),list(ord_dct.values()))
plt.title('Year vs Job_Openings')
plt.grid(True)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
import collections
with open('Datasets/amazon_jobs_dataset.csv', encoding ='UTF-8') as file_obj:
    file_data = csv.DictReader(file_obj, skipinitialspace=True)

    dct = {}
    for row in file_data:
        date = row['Posting_date'].split()
        key = date[0]
        if key in dct:
            dct[key] += 1
        else:
            dct[key] = 1
ord_dct = collections.OrderedDict(sorted(dct.items()))                                  
plt.bar(list(ord_dct.keys()),list(ord_dct.values()))
plt.xticks(rotation = 40)
plt.title('Month vs Job_Openings')

plt.show()

# %%
import csv
import matplotlib.pyplot as plt
import collections
with open('Datasets/amazon_jobs_dataset.csv', encoding ='UTF-8') as file_obj:
    file_data = csv.DictReader(file_obj, skipinitialspace=True)

    dct = {}
    for row in file_data:
        country = row['location'].split(',')[0]
        if country == 'IN' :
            key = row['location'].split(',')[2]
            if key in dct:
                dct[key] += 1
            else:
                dct[key] = 1
            
    ord_dct = collections.OrderedDict(sorted(dct.items()))                                  
    plt.pie(dct.values(),autopct='%0.2f',labels=dct.keys())
  
    plt.title(' Indian cities vs jobs_opening')
    plt.xticks(rotation = 40)
    plt.show()

# %%
import csv
import matplotlib.pyplot as plt
import collections
with open('Datasets/amazon_jobs_dataset.csv', encoding ='UTF-8') as file_obj:
    file_data = csv.DictReader(file_obj, skipinitialspace=True)

    dct = {}
    for row in file_data:
        qlfn = row['BASIC QUALIFICATIONS']
        if 'Java' in qlfn or 'java' in qlfn :
            key = row['Posting_date'].split()[2]
            if key in dct:
                dct[key] += 1
            else:
                dct[key] = 1
            
    ord_dct = collections.OrderedDict(sorted(dct.items()))                                  
    plt.plot(list(ord_dct.keys()),list(ord_dct.values()))
    
    plt.xlabel("Year")
    plt.ylabel("Jobs")
    plt.title('year vs No. of jobs opening related to Java')
    plt.xticks(rotation = 40)
    plt.show()
