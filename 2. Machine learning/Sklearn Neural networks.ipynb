# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split

# %%
iris = datasets.load_iris()

# %%
x = iris.data
y = iris.target

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y)

# %%
from sklearn.neural_network import MLPClassifier

# %%
clf = MLPClassifier(hidden_layer_sizes = (20, ), max_iter = 3000)
clf.fit(x_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(20,), max_iter=3000)

# %%
clf.score(x_test, y_test)
# Out:
# 0.9736842105263158

# %%
clf.coefs_ #it will give us all the features
# Out:
# [array([[ 3.25673140e-01, -2.59394609e-01,  1.72149553e-01,
#           1.53921589e-01,  2.39058350e-01,  5.75413039e-01,
#          -9.13828233e-02, -5.39941835e-06, -6.62319511e-13,
#          -2.67104008e-02, -2.25896675e-01,  8.45099685e-02,
#          -6.42787893e-20, -6.28624840e-05, -3.64114173e-01,
#           2.82699514e-01,  2.35683462e-34, -2.23129090e-05,
#           4.49770759e-01,  2.62001547e-01],
#         [ 8.09097855e-01, -1.54800638e-01, -5.96823187e-01,
#          -4.41572608e-01, -2.56771820e-01, -9.72553008e-02,
#          -6.09154786e-01,  1.41041650e-06, -1.61933629e-05,
#          -3.64637745e-01, -4.24208567e-01,  4.09470003e-01,
#          -9.51300228e-18,  1.07184343e-23, -1.91103338e-01,
#          -1.38592630e-03, -1.61146772e-16,  2.50672363e-12,
#          -5.92093398e-01,  9.38839823e-01],
#         [ 7.18609824e-02,  3.51337510e-01,  7.02893088e-01,
#           1.43434431e-01, -4.53001680e-01, -4.88744177e-01,
#           7.24439245e-01, -8.57782344e-23, -5.62263894e-04,
#           4.21251421e-02,  4.11640274e-01,  2.71266917e-01,
#          -9.95540883e-34,  2.30373932e-05,  3.53623388e-01,
#           2.83209765e-01, -2.75982979e-04, -1.40017267e-33,
#           4.69434307e-01, -9.68682863e-01],
#         [-4.65561707e-01, -7.83751589e-02,  1.27799383e+00,
#           3.39436321e-01, -1.87747038e-03, -4.31941401e-01,
#           1.44066573e+00,  2.64349201e-36, -6.74327910e-25,
#           2.14354210e-01, -4.23710585e-02, -3.35252127e-01,
#           3.80594578e-32, -1.14576996e-05,  4.05330769e-01,
#           2.10220787e-01, -9.81925051e-13,  1.49061697e-12,
#           3.34371152e-01, -1.00331477e+00]]),
#  array([[ 1.75856380e-01,  6.57636832e-01, -7.19586328e-01],
#         [ 1.79078215e-01,  7.38323874e-02, -1.67946043e-01],
#         [-5.53762161e-01, -2.43217485e-01,  4.36411970e-01],
#         [ 3.66097847e-01, -1.33272284e+00,  3.84581748e-01],
#         [-1.12494617e-01,  3.11475371e-01,  5.64222257e-02],
#         [ 1.70171625e-01,  4.35782338e-02, -1.23871304e+00],
#         [-5.43024559e-01, -2.79236757e-01,  1.54498627e+00],
#         [-2.56049739e-06,  3.71222168e-05, -4.99333653e-04],
#         [-3.53467261e-11, -1.05603050e-06, -1.21172635e-06],
#         [ 3.54306353e-02, -4.41888888e-01, -4.45042764e-01],
#         [ 3.06803855e-01, -1.26758852e-10,  1.71803936e-01],
#         [ 1.76993303e-01, -1.87287492e-01, -4.20470964e-01],
#         [ 7.47313273e-21,  3.29343947e-04, -3.58891872e-25],
#         [-7.21206988e-06,  2.86875009e-25, -5.81453898e-05],
#         [ 3.38500120e-01, -1.52140568e-01, -3.48143049e-01],
#         [ 2.69066273e-01, -3.05336833e-01, -1.08308844e-01],
#         [-1.28064342e-16,  4.18475428e-05,  5.57634008e-06],
#         [ 2.07555116e-13,  5.12851913e-37, -1.51632002e-09],
#         [-8.21143584e-01,  6.37253048e-01,  5.14774133e-01],
#         [ 1.06148655e+00, -1.13582827e+00, -8.88282709e-01]])]

# %%
len(clf.coefs_) #it reprsents the no. of layer
# Out:
# 2

# %%
clf.coefs_[0].shape, clf.coefs_[1].shape
# Out:
# ((4, 20), (20, 3))

# %%
clf.intercepts_[0].shape
# Out:
# (20,)
